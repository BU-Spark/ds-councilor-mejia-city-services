# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv("small business relief grant recipients 2020.csv")
df = df.dropna()
df.reset_index(drop=True)
df_N = df.groupby(['Neighborhood']).size().reset_index(name='counts')

# %%
plt.figure(figsize=(25,10))
neighborhood = df1['Neighborhood'].tolist()
cnt = df_N['counts'].tolist()
plt.bar(neighborhood, cnt, align='center')
y_pos = np.arange(len(neighborhood))
plt.xticks(y_pos, )
plt.ylabel('')
plt.title('')
plt.xticks(rotation=-15)
plt.show()
